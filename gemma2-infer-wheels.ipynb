# %%
# !pip download --no-deps -d /kaggle/working/wheels \
    --python-version 3.10 --only-binary=:all: \
    --platform manylinux2014_x86_64 --platform manylinux_2_24_x86_64 \
    tokenizers==0.19.1 huggingface_hub==0.23.4 safetensors==0.4.3 \
    peft==0.12.0 bitsandbytes==0.43.1
# !ls /kaggle/working/wheels
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 15.9 MB/s eta 0:00:00
# Saved ./wheels/tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./wheels/huggingface_hub-0.23.4-py3-none-any.whl
# Saved ./wheels/safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./wheels/peft-0.12.0-py3-none-any.whl
# Saved ./wheels/bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl
# Successfully downloaded tokenizers huggingface_hub safetensors peft bitsandbytes
# bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl
# huggingface_hub-0.23.4-py3-none-any.whl
# peft-0.12.0-py3-none-any.whl
# ...
